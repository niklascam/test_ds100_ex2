# %% [markdown]
# # GDP Analysis

# %%
# Import packages
from gdp import data, visualisation
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
FILE_NAME = "gdp.csv"
COUNTRY_CODES = ["GBR", "USA", "BRA", "JPN", "CHN", "DEU", "CHE"]
START_YEAR = 2000
END_YEAR = 2019

# %%
df = data.read_data(FILE_NAME)

# %%
df.head()
# Out:
# shape: (5, 68)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Country   ┆ Country   ┆ Indicator ┆ Indicator ┆ … ┆ 2020      ┆ 2021      ┆ 2022      ┆ 2023     │
# │ Name      ┆ Code      ┆ Name      ┆ Code      ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# │ str       ┆ str       ┆ str       ┆ str       ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Aruba     ┆ ABW       ┆ GDP       ┆ NY.GDP.MK ┆ … ┆ 2.5589e9  ┆ 3.1032e9  ┆ 3.5447e9  ┆ null     │
# │           ┆           ┆ (current  ┆ TP.CD     ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ US$)      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Africa    ┆ AFE       ┆ GDP       ┆ NY.GDP.MK ┆ … ┆ 9.2907e11 ┆ 1.0868e12 ┆ 1.1840e12 ┆ 1.2362e1 │
# │ Eastern   ┆           ┆ (current  ┆ TP.CD     ┆   ┆           ┆           ┆           ┆ 2        │
# │ and       ┆           ┆ US$)      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Southern  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Afghanist ┆ AFG       ┆ GDP       ┆ NY.GDP.MK ┆ … ┆ 1.9956e10 ┆ 1.4266e10 ┆ 1.4502e10 ┆ null     │
# │ an        ┆           ┆ (current  ┆ TP.CD     ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ US$)      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Africa    ┆ AFW       ┆ GDP       ┆ NY.GDP.MK ┆ … ┆ 7.8715e11 ┆ 8.4599e11 ┆ 8.7714e11 ┆ 7.9659e1 │
# │ Western   ┆           ┆ (current  ┆ TP.CD     ┆   ┆           ┆           ┆           ┆ 1        │
# │ and       ┆           ┆ US$)      ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Central   ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ Angola    ┆ AGO       ┆ GDP       ┆ NY.GDP.MK ┆ … ┆ 4.8502e10 ┆ 6.6505e10 ┆ 1.0440e11 ┆ 8.4723e1 │
# │           ┆           ┆ (current  ┆ TP.CD     ┆   ┆           ┆           ┆           ┆ 0        │
# │           ┆           ┆ US$)      ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
df_small = data.data_cleaner(df, COUNTRY_CODES, 2000, 2019)
df_small
# Out:
# shape: (133, 3)
# ┌───────────────┬──────┬───────────┐
# │ Country Name  ┆ Year ┆ GDP       │
# │ ---           ┆ ---  ┆ ---       │
# │ str           ┆ i32  ┆ f64       │
# ╞═══════════════╪══════╪═══════════╡
# │ Brazil        ┆ 2000 ┆ 6.5545e11 │
# │ Brazil        ┆ 2001 ┆ 5.5998e11 │
# │ Brazil        ┆ 2002 ┆ 5.0980e11 │
# │ Brazil        ┆ 2003 ┆ 5.5823e11 │
# │ Brazil        ┆ 2004 ┆ 6.6929e11 │
# │ …             ┆ …    ┆ …         │
# │ United States ┆ 2014 ┆ 1.7608e13 │
# │ United States ┆ 2015 ┆ 1.8295e13 │
# │ United States ┆ 2016 ┆ 1.8805e13 │
# │ United States ┆ 2017 ┆ 1.9612e13 │
# │ United States ┆ 2018 ┆ 2.0656e13 │
# └───────────────┴──────┴───────────┘

# %%
visualisation.plot_gdp(df_small)
# Out:
# <Axes: xlabel='Year', ylabel='GDP'>
