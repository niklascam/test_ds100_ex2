# %% [markdown]
# # GDP Analysis

# %%
from gdp import data, visualisation

# %%
FILE_NAME = "gdp.csv"
COUNTRY_CODES = ["GBR", "USA", "BRA", "JPN", "CHN", "DEU", "CHE"]
START_YEAR = 2000
END_YEAR = 2019

# %%
df = data.read_data(FILE_NAME)

# %%
df.head()
# Out:
# shape: (5, 69)
# ┌────────────┬────────────┬────────────┬────────────┬───┬───────────┬───────────┬───────────┬──────┐
# │ Country    ┆ Country    ┆ Indicator  ┆ Indicator  ┆ … ┆ 2021      ┆ 2022      ┆ 2023      ┆      │
# │ Name       ┆ Code       ┆ Name       ┆ Code       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---  │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆   ┆ str       ┆ str       ┆ str       ┆ str  │
# │ str        ┆ str        ┆ str        ┆ str        ┆   ┆           ┆           ┆           ┆      │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪══════╡
# │ Aruba      ┆ ABW        ┆ GDP        ┆ NY.GDP.MKT ┆ … ┆ 310318410 ┆ 354470778 ┆           ┆ null │
# │            ┆            ┆ (current   ┆ P.CD       ┆   ┆ 1.51354   ┆ 8.05664   ┆           ┆      │
# │            ┆            ┆ US$)       ┆            ┆   ┆           ┆           ┆           ┆      │
# │ Africa     ┆ AFE        ┆ GDP        ┆ NY.GDP.MKT ┆ … ┆ 108677216 ┆ 118396213 ┆ 123616304 ┆ null │
# │ Eastern    ┆            ┆ (current   ┆ P.CD       ┆   ┆ 4579.87   ┆ 3998.87   ┆ 4999.97   ┆      │
# │ and        ┆            ┆ US$)       ┆            ┆   ┆           ┆           ┆           ┆      │
# │ Southern   ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ Afghanista ┆ AFG        ┆ GDP        ┆ NY.GDP.MKT ┆ … ┆ 142664994 ┆ 145021581 ┆           ┆ null │
# │ n          ┆            ┆ (current   ┆ P.CD       ┆   ┆ 29.8746   ┆ 92.0904   ┆           ┆      │
# │            ┆            ┆ US$)       ┆            ┆   ┆           ┆           ┆           ┆      │
# │ Africa     ┆ AFW        ┆ GDP        ┆ NY.GDP.MKT ┆ … ┆ 845993047 ┆ 877140805 ┆ 796586157 ┆ null │
# │ Western    ┆            ┆ (current   ┆ P.CD       ┆   ┆ 006.805   ┆ 320.357   ┆ 553.094   ┆      │
# │ and        ┆            ┆ US$)       ┆            ┆   ┆           ┆           ┆           ┆      │
# │ Central    ┆            ┆            ┆            ┆   ┆           ┆           ┆           ┆      │
# │ Angola     ┆ AGO        ┆ GDP        ┆ NY.GDP.MKT ┆ … ┆ 665051299 ┆ 104399746 ┆ 847229576 ┆ null │
# │            ┆            ┆ (current   ┆ P.CD       ┆   ┆ 87.7235   ┆ 853.401   ┆ 42.3757   ┆      │
# │            ┆            ┆ US$)       ┆            ┆   ┆           ┆           ┆           ┆      │
# └────────────┴────────────┴────────────┴────────────┴───┴───────────┴───────────┴───────────┴──────┘

# %%
df_small = data.data_cleaner(df, COUNTRY_CODES, 2000, 2019)
df_small
# Out:
# shape: (133, 3)
# ┌───────────────┬──────┬───────────┐
# │ Country Name  ┆ Year ┆ GDP       │
# │ ---           ┆ ---  ┆ ---       │
# │ str           ┆ i32  ┆ f64       │
# ╞═══════════════╪══════╪═══════════╡
# │ Brazil        ┆ 2000 ┆ 6.5545e11 │
# │ Brazil        ┆ 2001 ┆ 5.5998e11 │
# │ Brazil        ┆ 2002 ┆ 5.0980e11 │
# │ Brazil        ┆ 2003 ┆ 5.5823e11 │
# │ Brazil        ┆ 2004 ┆ 6.6929e11 │
# │ …             ┆ …    ┆ …         │
# │ United States ┆ 2014 ┆ 1.7608e13 │
# │ United States ┆ 2015 ┆ 1.8295e13 │
# │ United States ┆ 2016 ┆ 1.8805e13 │
# │ United States ┆ 2017 ┆ 1.9612e13 │
# │ United States ┆ 2018 ┆ 2.0657e13 │
# └───────────────┴──────┴───────────┘

# %%
visualisation.plot_gdp(df_small)
# Out:
# <Axes: xlabel='Year', ylabel='GDP'>
